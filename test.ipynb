# %%
import cv2
import os
import numpy as np
from skimage.transform import hough_line, hough_line_peaks
from skimage.feature import canny
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu
import pytesseract
from pytesseract import Output
from scipy.stats import mode
from scipy.ndimage import median_filter
from skimage import  filters , io
import matplotlib.pyplot as plt
from skimage.filters import gaussian

 
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract.exe'  # your path may be different

# imgPath = '899.jpeg'

def binarizeImage(imgPath):

  # Load the image
    # image = cv2.imread(imgPath)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(imgPath, cv2.COLOR_BGR2GRAY)

    # Threshold the image to get a binary image
    _, binary_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    count = binary_image[0,0]+binary_image[-1,0]+binary_image[0,-1]+binary_image[-1,-1]
    # Invert the binary image to get black text on white background
    if count<2:
        binary_image = cv2.bitwise_not(binary_image)
    # Convert the image to black text on white background
    black_text_on_white = cv2.cvtColor(binary_image, cv2.COLOR_GRAY2BGR)
    # Save or display the resulting image
    # cv2.imwrite('binary_img.jpeg', ~black_text_on_white)
    return black_text_on_white

def rotate_image(image, angle):
    # print('angle:', angle)
    # Get image dimensions
    # image = cv2.imread(image_path)
    # cv2.imwrite('befor_hough_out.jpeg', image)
    h, w = image.shape[:2]
    # Calculate rotation matrix
    background_color =tuple( image[0, 0])
    rotation_matrix = cv2.getRotationMatrix2D((w / 2, h / 2), angle, 1)
    # Perform rotation
    rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_CONSTANT)
    # Create a mask for the rotated image
    mask = np.ones_like(rotated_image) * background_color
    # Overlay the rotated image on the mask
    result = np.where(rotated_image == background_color, mask, rotated_image)
    return result

def hough_transforms(image) :
    # Read the image
    # image = cv2.imread(image)
    
    # Convert image to grayscale

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Apply Gaussian blur
    thresh = cv2.GaussianBlur(gray, (11, 11), 0)
    
    # Detect edges using Canny
    edges = canny(thresh)

    # Define tested angles for Hough transform
    tested_angles = np.deg2rad(np.arange(0, 180.0))
    
    # Perform Hough transform
    h, theta, d = hough_line(edges, theta=tested_angles)
    
    lined_image = np.copy(image)
    # Find peaks in Hough space
    accum, angles, dists = hough_line_peaks(h, theta, d, num_peaks=10)
    for angle, dist in zip(angles, dists):
    # Check if sin(angle) is close to zero (vertical line)
        if np.isclose(np.sin(angle), 0):
            # Handle vertical lines separately
            x = int(dist)
            cv2.line(lined_image, (x, 0), (x, lined_image.shape[0]), (0, 255, 0), 2)
        else:
            # Calculate y0 and y1 for non-vertical lines
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - lined_image.shape[1] * np.cos(angle)) / np.sin(angle)
            # Ensure y0 and y1 are finite
            if np.isfinite(y0) and np.isfinite(y1):
                cv2.line(lined_image, (0, int(y0)), (lined_image.shape[1], int(y1)), (0, 255, 0), 2)
    # cv2.imwrite('outlined.jpg', lined_image)
    # Print the detected angles
    # print('Number of lines detected:', len(angles))
    # print('Detected angles(rad):', angles)
    angles = angles * (180 / np.pi)
    # angles = angles[np.round(angles) != 90]
    rotation_angle = mode(angles).mode if len(angles)>0  else 0
    # print('Detected angles(degree):', angles)
    rotation_angle = mode(angles).mode if len(angles)>0  else 0
    if (rotation_angle < 15 ):
        rotation_angle = 0    
    else:
        rotation_angle = rotation_angle - 90
    # Rotate the image using the first detected angle
    # print('rotation angle:', rotation_angle)
    # cv2.imwrite('befor_befor_hough_out.jpeg', image)
    rotated_image = rotate_image(image,  rotation_angle)
    # Save the rotated image
    # cv2.imwrite('hough_out.jpeg', rotated_image)

    return rotated_image


def pytesseract_orientation(image_path):
    osd = None
    try:
        osd = pytesseract.image_to_osd(image_path, config=' --psm 0 -c min_characters_to_try=10', output_type=Output.DICT)
    except Exception as e:
        # print("Error: " + str(e))
        return image_path

    # print("[OSD] " + str(osd))

    # If the orientation is detected as 180 degrees and the script orientation is not 0, rotate by 180 degrees
    if osd["orientation"] == 180 and osd["script"] != "Latin":
        rotated = rotate_image(image_path, angle=180)
        # cv2.imwrite('correct_orient.jpeg', rotated)
        return rotated
    else:
        # If the orientation is detected as 180 degrees but the script orientation is 0, return the original image
        if osd["orientation"] == 180:
            return image_path
        else:
            rotated = rotate_image(image_path, angle=osd["orientation"])
            # cv2.imwrite('correct_orient.jpeg', rotated)
            return rotated



def preprocess(input_path, output_path):
    image = cv2.imread(input_path)
    output_image=filters.median(image)
    # cv2.imwrite('after_median.jpeg', output_image)
    binary_image = binarizeImage(output_image)
    # cv2.imwrite('after_color.jpeg', binary_image)
    # output_image_gaussian = gaussian(image, sigma=1)
    hough_out = hough_transforms(image=binary_image)
    # cv2.imwrite('after_hough.jpeg', hough_out)
    correct_orient = pytesseract_orientation(hough_out)
    cv2.imwrite(output_path, correct_orient)

def process_images_in_folder(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through files and subfolders in the input folder
    for root, _, files in os.walk(input_folder):
        # Create corresponding subfolder in the output folder
        relative_path = os.path.relpath(root, input_folder)
        output_subfolder = os.path.join(output_folder, relative_path)
        os.makedirs(output_subfolder, exist_ok=True)

        # Process files in the current folder
        for filename in files:
            # Check if the file is an image
            if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
                # Get the input and output paths
                input_path = os.path.join(root, filename)
                output_path = os.path.join(output_subfolder, filename)
                print(f"Processing {input_path}...")
                # Process the image
                preprocess(input_path, output_path)


input_root_folder = "images/train/Lemonada/"
output_root_folder = "images/train/output/Lemonada/"


process_images_in_folder(input_root_folder, output_root_folder)
# preprocess(input_root_folder, output_root_folder)
# Out:
# Processing images/train/Lemonada/0.jpeg...
# Processing images/train/Lemonada/1.jpeg...
# Processing images/train/Lemonada/10.jpeg...
# Processing images/train/Lemonada/100.jpeg...
# C:\Users\20112\AppData\Local\Temp\ipykernel_15548\779025818.py:31: RuntimeWarning: overflow encountered in scalar add
#   count = binary_image[0,0]+binary_image[-1,0]+binary_image[0,-1]+binary_image[-1,-1]
# Processing images/train/Lemonada/101.jpeg...
# Processing images/train/Lemonada/102.jpeg...
# Processing images/train/Lemonada/103.jpeg...
# Processing images/train/Lemonada/104.jpeg...
# Processing images/train/Lemonada/105.jpeg...
# Processing images/train/Lemonada/106.jpeg...
# Processing images/train/Lemonada/107.jpeg...
# Processing images/train/Lemonada/108.jpeg...
# Processing images/train/Lemonada/109.jpeg...
# Processing images/train/Lemonada/11.jpeg...
# Processing images/train/Lemonada/110.jpeg...
# Processing images/train/Lemonada/111.jpeg...
# Processing images/train/Lemonada/112.jpeg...
# Processing images/train/Lemonada/113.jpeg...
# Processing images/train/Lemonada/114.jpeg...
# Processing images/train/Lemonada/115.jpeg...
# Processing images/train/Lemonada/116.jpeg...
# Processing images/train/Lemonada/117.jpeg...
# Processing images/train/Lemonada/118.jpeg...
# Processing images/train/Lemonada/119.jpeg...
# Processing images/train/Lemonada/12.jpeg...
# Processing images/train/Lemonada/120.jpeg...
# Processing images/train/Lemonada/121.jpeg...
# Processing images/train/Lemonada/122.jpeg...
# Processing images/train/Lemonada/123.jpeg...
# Processing images/train/Lemonada/124.jpeg...
# Processing images/train/Lemonada/125.jpeg...
# Processing images/train/Lemonada/126.jpeg...
# Processing images/train/Lemonada/127.jpeg...
# Processing images/train/Lemonada/128.jpeg...
# Processing images/train/Lemonada/129.jpeg...
# Processing images/train/Lemonada/13.jpeg...
# Processing images/train/Lemonada/130.jpeg...
# Processing images/train/Lemonada/131.jpeg...
# Processing images/train/Lemonada/132.jpeg...
# Processing images/train/Lemonada/133.jpeg...
# Processing images/train/Lemonada/134.jpeg...
# Processing images/train/Lemonada/135.jpeg...
# Processing images/train/Lemonada/136.jpeg...
# Processing images/train/Lemonada/137.jpeg...
# Processing images/train/Lemonada/138.jpeg...
# Processing images/train/Lemonada/139.jpeg...
# Processing images/train/Lemonada/14.jpeg...
# Processing images/train/Lemonada/140.jpeg...
# Processing images/train/Lemonada/141.jpeg...
# Processing images/train/Lemonada/142.jpeg...
# Processing images/train/Lemonada/143.jpeg...
# Processing images/train/Lemonada/144.jpeg...
# Processing images/train/Lemonada/145.jpeg...
# Processing images/train/Lemonada/146.jpeg...
# Processing images/train/Lemonada/147.jpeg...
# Processing images/train/Lemonada/148.jpeg...
# Processing images/train/Lemonada/149.jpeg...
# Processing images/train/Lemonada/15.jpeg...
# Processing images/train/Lemonada/150.jpeg...
# Processing images/train/Lemonada/151.jpeg...
# Processing images/train/Lemonada/152.jpeg...
# Processing images/train/Lemonada/153.jpeg...
# Processing images/train/Lemonada/154.jpeg...
# Processing images/train/Lemonada/155.jpeg...
# Processing images/train/Lemonada/156.jpeg...
# Processing images/train/Lemonada/157.jpeg...
# Processing images/train/Lemonada/158.jpeg...
# Processing images/train/Lemonada/159.jpeg...
# Processing images/train/Lemonada/16.jpeg...
# Processing images/train/Lemonada/160.jpeg...
# Processing images/train/Lemonada/161.jpeg...
# Processing images/train/Lemonada/162.jpeg...
# Processing images/train/Lemonada/163.jpeg...
# Processing images/train/Lemonada/164.jpeg...
# Processing images/train/Lemonada/165.jpeg...
# Processing images/train/Lemonada/166.jpeg...
# Processing images/train/Lemonada/167.jpeg...
# Processing images/train/Lemonada/168.jpeg...
# Processing images/train/Lemonada/169.jpeg...
# Processing images/train/Lemonada/17.jpeg...
# Processing images/train/Lemonada/170.jpeg...
# Processing images/train/Lemonada/171.jpeg...
# Processing images/train/Lemonada/172.jpeg...
# Processing images/train/Lemonada/173.jpeg...
# Processing images/train/Lemonada/174.jpeg...
# Processing images/train/Lemonada/175.jpeg...
# Processing images/train/Lemonada/176.jpeg...
# Processing images/train/Lemonada/177.jpeg...
# Processing images/train/Lemonada/178.jpeg...
# Processing images/train/Lemonada/179.jpeg...
# Processing images/train/Lemonada/18.jpeg...
# Processing images/train/Lemonada/180.jpeg...
# Processing images/train/Lemonada/181.jpeg...
# Processing images/train/Lemonada/182.jpeg...
# Processing images/train/Lemonada/183.jpeg...
# Processing images/train/Lemonada/184.jpeg...
# Processing images/train/Lemonada/185.jpeg...
# Processing images/train/Lemonada/186.jpeg...
# Processing images/train/Lemonada/187.jpeg...
# Processing images/train/Lemonada/188.jpeg...
# Processing images/train/Lemonada/189.jpeg...
# Processing images/train/Lemonada/19.jpeg...
# Processing images/train/Lemonada/190.jpeg...
# Processing images/train/Lemonada/191.jpeg...
# Processing images/train/Lemonada/192.jpeg...
# Processing images/train/Lemonada/193.jpeg...
# Processing images/train/Lemonada/194.jpeg...
# Processing images/train/Lemonada/195.jpeg...
# Processing images/train/Lemonada/196.jpeg...
# Processing images/train/Lemonada/197.jpeg...
# Processing images/train/Lemonada/198.jpeg...
# Processing images/train/Lemonada/199.jpeg...
# Processing images/train/Lemonada/2.jpeg...
# Processing images/train/Lemonada/20.jpeg...
# Processing images/train/Lemonada/200.jpeg...
# Processing images/train/Lemonada/201.jpeg...
# Processing images/train/Lemonada/202.jpeg...
# Processing images/train/Lemonada/203.jpeg...
# Processing images/train/Lemonada/204.jpeg...
# Processing images/train/Lemonada/205.jpeg...
# Processing images/train/Lemonada/206.jpeg...
# Processing images/train/Lemonada/207.jpeg...
# Processing images/train/Lemonada/208.jpeg...
# Processing images/train/Lemonada/209.jpeg...
# Processing images/train/Lemonada/21.jpeg...
# Processing images/train/Lemonada/210.jpeg...
# Processing images/train/Lemonada/211.jpeg...
# Processing images/train/Lemonada/212.jpeg...
# Processing images/train/Lemonada/213.jpeg...
# Processing images/train/Lemonada/214.jpeg...
# Processing images/train/Lemonada/215.jpeg...
# Processing images/train/Lemonada/216.jpeg...
# Processing images/train/Lemonada/217.jpeg...
# Processing images/train/Lemonada/218.jpeg...
# Processing images/train/Lemonada/219.jpeg...
# Processing images/train/Lemonada/22.jpeg...
# Processing images/train/Lemonada/220.jpeg...
# Processing images/train/Lemonada/221.jpeg...
# Processing images/train/Lemonada/222.jpeg...
# Processing images/train/Lemonada/223.jpeg...
# Processing images/train/Lemonada/224.jpeg...
# Processing images/train/Lemonada/225.jpeg...
# Processing images/train/Lemonada/226.jpeg...
# Processing images/train/Lemonada/227.jpeg...
# Processing images/train/Lemonada/228.jpeg...
# Processing images/train/Lemonada/229.jpeg...
# Processing images/train/Lemonada/23.jpeg...
# Processing images/train/Lemonada/230.jpeg...
# Processing images/train/Lemonada/231.jpeg...
# Processing images/train/Lemonada/232.jpeg...
# Processing images/train/Lemonada/233.jpeg...
# Processing images/train/Lemonada/234.jpeg...
# Processing images/train/Lemonada/235.jpeg...
# Processing images/train/Lemonada/236.jpeg...
# Processing images/train/Lemonada/237.jpeg...
# Processing images/train/Lemonada/238.jpeg...
# Processing images/train/Lemonada/239.jpeg...
# Processing images/train/Lemonada/24.jpeg...
# Processing images/train/Lemonada/240.jpeg...
# Processing images/train/Lemonada/241.jpeg...
# Processing images/train/Lemonada/242.jpeg...
# Processing images/train/Lemonada/243.jpeg...
# Processing images/train/Lemonada/244.jpeg...
# Processing images/train/Lemonada/245.jpeg...
# Processing images/train/Lemonada/246.jpeg...
# Processing images/train/Lemonada/247.jpeg...
# Processing images/train/Lemonada/248.jpeg...
# Processing images/train/Lemonada/249.jpeg...
# Processing images/train/Lemonada/25.jpeg...
# Processing images/train/Lemonada/250.jpeg...
# Processing images/train/Lemonada/251.jpeg...
# Processing images/train/Lemonada/252.jpeg...
# Processing images/train/Lemonada/253.jpeg...
# Processing images/train/Lemonada/254.jpeg...
# Processing images/train/Lemonada/255.jpeg...
# Processing images/train/Lemonada/256.jpeg...
# Processing images/train/Lemonada/257.jpeg...
# Processing images/train/Lemonada/258.jpeg...
# Processing images/train/Lemonada/259.jpeg...
# Processing images/train/Lemonada/26.jpeg...
# Processing images/train/Lemonada/260.jpeg...
# Processing images/train/Lemonada/261.jpeg...
# Processing images/train/Lemonada/262.jpeg...
# Processing images/train/Lemonada/263.jpeg...
# Processing images/train/Lemonada/264.jpeg...
# Processing images/train/Lemonada/265.jpeg...
# Processing images/train/Lemonada/266.jpeg...
# Processing images/train/Lemonada/267.jpeg...
# Processing images/train/Lemonada/268.jpeg...
# Processing images/train/Lemonada/269.jpeg...
# Processing images/train/Lemonada/27.jpeg...
# Processing images/train/Lemonada/270.jpeg...
# Processing images/train/Lemonada/271.jpeg...
# Processing images/train/Lemonada/272.jpeg...
# Processing images/train/Lemonada/273.jpeg...
# Processing images/train/Lemonada/274.jpeg...
# Processing images/train/Lemonada/275.jpeg...
# Processing images/train/Lemonada/276.jpeg...
# Processing images/train/Lemonada/277.jpeg...
# Processing images/train/Lemonada/278.jpeg...
# Processing images/train/Lemonada/279.jpeg...
# Processing images/train/Lemonada/28.jpeg...
# Processing images/train/Lemonada/280.jpeg...
# Processing images/train/Lemonada/281.jpeg...
# Processing images/train/Lemonada/282.jpeg...
# Processing images/train/Lemonada/283.jpeg...
# Processing images/train/Lemonada/284.jpeg...
# Processing images/train/Lemonada/285.jpeg...
# Processing images/train/Lemonada/286.jpeg...
# Processing images/train/Lemonada/287.jpeg...
# Processing images/train/Lemonada/288.jpeg...
# Processing images/train/Lemonada/289.jpeg...
# Processing images/train/Lemonada/29.jpeg...
# Processing images/train/Lemonada/290.jpeg...
# Processing images/train/Lemonada/291.jpeg...
# Processing images/train/Lemonada/292.jpeg...
# Processing images/train/Lemonada/293.jpeg...
# Processing images/train/Lemonada/294.jpeg...
# Processing images/train/Lemonada/295.jpeg...
# Processing images/train/Lemonada/296.jpeg...
# Processing images/train/Lemonada/297.jpeg...
# Processing images/train/Lemonada/298.jpeg...
# Processing images/train/Lemonada/299.jpeg...
# Processing images/train/Lemonada/3.jpeg...
# Processing images/train/Lemonada/30.jpeg...
# Processing images/train/Lemonada/300.jpeg...
# Processing images/train/Lemonada/301.jpeg...
# Processing images/train/Lemonada/302.jpeg...
# Processing images/train/Lemonada/303.jpeg...
# Processing images/train/Lemonada/304.jpeg...
# Processing images/train/Lemonada/305.jpeg...
# Processing images/train/Lemonada/306.jpeg...
# Processing images/train/Lemonada/307.jpeg...
# Processing images/train/Lemonada/308.jpeg...
# Processing images/train/Lemonada/309.jpeg...
# Processing images/train/Lemonada/31.jpeg...
# Processing images/train/Lemonada/310.jpeg...
# Processing images/train/Lemonada/311.jpeg...
# Processing images/train/Lemonada/312.jpeg...
# Processing images/train/Lemonada/313.jpeg...
# Processing images/train/Lemonada/314.jpeg...
# Processing images/train/Lemonada/315.jpeg...
# Processing images/train/Lemonada/316.jpeg...
# Processing images/train/Lemonada/317.jpeg...
# Processing images/train/Lemonada/318.jpeg...
# Processing images/train/Lemonada/319.jpeg...
# Processing images/train/Lemonada/32.jpeg...
# Processing images/train/Lemonada/320.jpeg...
# Processing images/train/Lemonada/321.jpeg...
# Processing images/train/Lemonada/322.jpeg...
# Processing images/train/Lemonada/323.jpeg...
# Processing images/train/Lemonada/324.jpeg...
# Processing images/train/Lemonada/325.jpeg...
# Processing images/train/Lemonada/326.jpeg...
# Processing images/train/Lemonada/327.jpeg...
# Processing images/train/Lemonada/328.jpeg...
# Processing images/train/Lemonada/329.jpeg...
# Processing images/train/Lemonada/33.jpeg...
# Processing images/train/Lemonada/330.jpeg...
# Processing images/train/Lemonada/331.jpeg...
# Processing images/train/Lemonada/332.jpeg...
# Processing images/train/Lemonada/333.jpeg...
# Processing images/train/Lemonada/334.jpeg...
# Processing images/train/Lemonada/335.jpeg...
# Processing images/train/Lemonada/336.jpeg...
# Processing images/train/Lemonada/337.jpeg...
# Processing images/train/Lemonada/338.jpeg...
# Processing images/train/Lemonada/339.jpeg...
# Processing images/train/Lemonada/34.jpeg...
# Processing images/train/Lemonada/340.jpeg...
# Processing images/train/Lemonada/341.jpeg...
# Processing images/train/Lemonada/342.jpeg...
# Processing images/train/Lemonada/343.jpeg...
# Processing images/train/Lemonada/344.jpeg...
# Processing images/train/Lemonada/345.jpeg...
# Processing images/train/Lemonada/346.jpeg...
# Processing images/train/Lemonada/347.jpeg...
# Processing images/train/Lemonada/348.jpeg...
# Processing images/train/Lemonada/349.jpeg...
# Processing images/train/Lemonada/35.jpeg...
# Processing images/train/Lemonada/350.jpeg...
# Processing images/train/Lemonada/351.jpeg...
# Processing images/train/Lemonada/352.jpeg...
# Processing images/train/Lemonada/353.jpeg...
# Processing images/train/Lemonada/354.jpeg...
# Processing images/train/Lemonada/355.jpeg...
# Processing images/train/Lemonada/356.jpeg...
# Processing images/train/Lemonada/357.jpeg...
# Processing images/train/Lemonada/358.jpeg...
# Processing images/train/Lemonada/359.jpeg...
# Processing images/train/Lemonada/36.jpeg...
# Processing images/train/Lemonada/360.jpeg...
# Processing images/train/Lemonada/361.jpeg...
# Processing images/train/Lemonada/362.jpeg...
# Processing images/train/Lemonada/363.jpeg...
# Processing images/train/Lemonada/364.jpeg...
# Processing images/train/Lemonada/365.jpeg...
# Processing images/train/Lemonada/366.jpeg...
# Processing images/train/Lemonada/367.jpeg...
# Processing images/train/Lemonada/368.jpeg...
# Processing images/train/Lemonada/369.jpeg...
# Processing images/train/Lemonada/37.jpeg...
# Processing images/train/Lemonada/370.jpeg...
# Processing images/train/Lemonada/371.jpeg...
# Processing images/train/Lemonada/372.jpeg...
# Processing images/train/Lemonada/373.jpeg...
# Processing images/train/Lemonada/374.jpeg...
# Processing images/train/Lemonada/375.jpeg...
# Processing images/train/Lemonada/376.jpeg...
# Processing images/train/Lemonada/377.jpeg...
# Processing images/train/Lemonada/378.jpeg...
# Processing images/train/Lemonada/379.jpeg...
# Processing images/train/Lemonada/38.jpeg...
# Processing images/train/Lemonada/380.jpeg...
# Processing images/train/Lemonada/381.jpeg...
# Processing images/train/Lemonada/382.jpeg...
# Processing images/train/Lemonada/383.jpeg...
# Processing images/train/Lemonada/384.jpeg...
# Processing images/train/Lemonada/385.jpeg...
# Processing images/train/Lemonada/386.jpeg...
# Processing images/train/Lemonada/387.jpeg...
# Processing images/train/Lemonada/388.jpeg...
# Processing images/train/Lemonada/389.jpeg...
# Processing images/train/Lemonada/39.jpeg...
# Processing images/train/Lemonada/390.jpeg...
# Processing images/train/Lemonada/391.jpeg...
# Processing images/train/Lemonada/392.jpeg...
# Processing images/train/Lemonada/393.jpeg...
# Processing images/train/Lemonada/394.jpeg...
# Processing images/train/Lemonada/395.jpeg...
# Processing images/train/Lemonada/396.jpeg...
# Processing images/train/Lemonada/397.jpeg...
# Processing images/train/Lemonada/398.jpeg...
# Processing images/train/Lemonada/399.jpeg...
# Processing images/train/Lemonada/4.jpeg...
# Processing images/train/Lemonada/40.jpeg...
# Processing images/train/Lemonada/400.jpeg...
# Processing images/train/Lemonada/401.jpeg...
# Processing images/train/Lemonada/402.jpeg...
# Processing images/train/Lemonada/403.jpeg...
# Processing images/train/Lemonada/404.jpeg...
# Processing images/train/Lemonada/405.jpeg...
# Processing images/train/Lemonada/406.jpeg...
# Processing images/train/Lemonada/407.jpeg...
# Processing images/train/Lemonada/408.jpeg...
# Processing images/train/Lemonada/409.jpeg...
# Processing images/train/Lemonada/41.jpeg...
# Processing images/train/Lemonada/410.jpeg...
# Processing images/train/Lemonada/411.jpeg...
# Processing images/train/Lemonada/412.jpeg...
# Processing images/train/Lemonada/413.jpeg...
# Processing images/train/Lemonada/414.jpeg...
# Processing images/train/Lemonada/415.jpeg...
# Processing images/train/Lemonada/416.jpeg...
# Processing images/train/Lemonada/417.jpeg...
# Processing images/train/Lemonada/418.jpeg...
# Processing images/train/Lemonada/419.jpeg...
# Processing images/train/Lemonada/42.jpeg...
# Processing images/train/Lemonada/420.jpeg...
# Processing images/train/Lemonada/421.jpeg...
# Processing images/train/Lemonada/422.jpeg...
# Processing images/train/Lemonada/423.jpeg...
# Processing images/train/Lemonada/424.jpeg...
# Processing images/train/Lemonada/425.jpeg...
# Processing images/train/Lemonada/426.jpeg...
# Processing images/train/Lemonada/427.jpeg...
# Processing images/train/Lemonada/428.jpeg...
# Processing images/train/Lemonada/429.jpeg...
# Processing images/train/Lemonada/43.jpeg...
# Processing images/train/Lemonada/430.jpeg...
# Processing images/train/Lemonada/431.jpeg...
# Processing images/train/Lemonada/432.jpeg...
# Processing images/train/Lemonada/433.jpeg...
# Processing images/train/Lemonada/434.jpeg...
# Processing images/train/Lemonada/435.jpeg...
# Processing images/train/Lemonada/436.jpeg...
# Processing images/train/Lemonada/437.jpeg...
# Processing images/train/Lemonada/438.jpeg...
# Processing images/train/Lemonada/439.jpeg...
# Processing images/train/Lemonada/44.jpeg...
# Processing images/train/Lemonada/440.jpeg...
# Processing images/train/Lemonada/441.jpeg...
# Processing images/train/Lemonada/442.jpeg...
# Processing images/train/Lemonada/443.jpeg...
# Processing images/train/Lemonada/444.jpeg...
# Processing images/train/Lemonada/445.jpeg...
# Processing images/train/Lemonada/446.jpeg...
# Processing images/train/Lemonada/447.jpeg...
# Processing images/train/Lemonada/448.jpeg...
# Processing images/train/Lemonada/449.jpeg...
# Processing images/train/Lemonada/45.jpeg...
# Processing images/train/Lemonada/450.jpeg...
# Processing images/train/Lemonada/451.jpeg...
# Processing images/train/Lemonada/452.jpeg...
# Processing images/train/Lemonada/453.jpeg...
# Processing images/train/Lemonada/454.jpeg...
# Processing images/train/Lemonada/455.jpeg...
# Processing images/train/Lemonada/456.jpeg...
# Processing images/train/Lemonada/457.jpeg...
# Processing images/train/Lemonada/458.jpeg...
# Processing images/train/Lemonada/459.jpeg...
# Processing images/train/Lemonada/46.jpeg...
# Processing images/train/Lemonada/460.jpeg...
# Processing images/train/Lemonada/461.jpeg...
# Processing images/train/Lemonada/462.jpeg...
# Processing images/train/Lemonada/463.jpeg...
# Processing images/train/Lemonada/464.jpeg...
# Processing images/train/Lemonada/465.jpeg...
# Processing images/train/Lemonada/466.jpeg...
# Processing images/train/Lemonada/467.jpeg...
# Processing images/train/Lemonada/468.jpeg...
# Processing images/train/Lemonada/469.jpeg...
# Processing images/train/Lemonada/47.jpeg...
# Processing images/train/Lemonada/470.jpeg...
# Processing images/train/Lemonada/471.jpeg...
# Processing images/train/Lemonada/472.jpeg...
# Processing images/train/Lemonada/473.jpeg...
# Processing images/train/Lemonada/474.jpeg...
# Processing images/train/Lemonada/475.jpeg...
# Processing images/train/Lemonada/476.jpeg...
# Processing images/train/Lemonada/477.jpeg...
# Processing images/train/Lemonada/478.jpeg...
# Processing images/train/Lemonada/479.jpeg...
# Processing images/train/Lemonada/48.jpeg...
# Processing images/train/Lemonada/480.jpeg...
# Processing images/train/Lemonada/481.jpeg...
# Processing images/train/Lemonada/482.jpeg...
# Processing images/train/Lemonada/483.jpeg...
# Processing images/train/Lemonada/484.jpeg...
# Processing images/train/Lemonada/485.jpeg...
# Processing images/train/Lemonada/486.jpeg...
# Processing images/train/Lemonada/487.jpeg...
# Processing images/train/Lemonada/488.jpeg...
# Processing images/train/Lemonada/489.jpeg...
# Processing images/train/Lemonada/49.jpeg...
# Processing images/train/Lemonada/490.jpeg...
# Processing images/train/Lemonada/491.jpeg...
# Processing images/train/Lemonada/492.jpeg...
# Processing images/train/Lemonada/493.jpeg...
# Processing images/train/Lemonada/494.jpeg...
# Processing images/train/Lemonada/495.jpeg...
# Processing images/train/Lemonada/496.jpeg...
# Processing images/train/Lemonada/497.jpeg...
# Processing images/train/Lemonada/498.jpeg...
# Processing images/train/Lemonada/499.jpeg...
# Processing images/train/Lemonada/5.jpeg...
# Processing images/train/Lemonada/50.jpeg...
# Processing images/train/Lemonada/500.jpeg...
# Processing images/train/Lemonada/501.jpeg...
# Processing images/train/Lemonada/502.jpeg...
# Processing images/train/Lemonada/503.jpeg...
# Processing images/train/Lemonada/504.jpeg...
# Processing images/train/Lemonada/505.jpeg...
# Processing images/train/Lemonada/506.jpeg...
# Processing images/train/Lemonada/507.jpeg...
# Processing images/train/Lemonada/508.jpeg...
# Processing images/train/Lemonada/509.jpeg...
# Processing images/train/Lemonada/51.jpeg...
# Processing images/train/Lemonada/510.jpeg...
# Processing images/train/Lemonada/511.jpeg...
# Processing images/train/Lemonada/512.jpeg...
# Processing images/train/Lemonada/513.jpeg...
# Processing images/train/Lemonada/514.jpeg...
# Processing images/train/Lemonada/515.jpeg...
# Processing images/train/Lemonada/516.jpeg...
# Processing images/train/Lemonada/517.jpeg...
# Processing images/train/Lemonada/518.jpeg...
# Processing images/train/Lemonada/519.jpeg...
# Processing images/train/Lemonada/52.jpeg...
# Processing images/train/Lemonada/520.jpeg...
# Processing images/train/Lemonada/521.jpeg...
# Processing images/train/Lemonada/522.jpeg...
# Processing images/train/Lemonada/523.jpeg...
# Processing images/train/Lemonada/524.jpeg...
# Processing images/train/Lemonada/525.jpeg...
# Processing images/train/Lemonada/526.jpeg...
# Processing images/train/Lemonada/527.jpeg...
# Processing images/train/Lemonada/528.jpeg...
# Processing images/train/Lemonada/529.jpeg...
# Processing images/train/Lemonada/53.jpeg...
# Processing images/train/Lemonada/530.jpeg...
# Processing images/train/Lemonada/531.jpeg...
# Processing images/train/Lemonada/532.jpeg...
# Processing images/train/Lemonada/533.jpeg...
# Processing images/train/Lemonada/534.jpeg...
# Processing images/train/Lemonada/535.jpeg...
# Processing images/train/Lemonada/536.jpeg...
# Processing images/train/Lemonada/537.jpeg...
# Processing images/train/Lemonada/538.jpeg...
# Processing images/train/Lemonada/539.jpeg...
# Processing images/train/Lemonada/54.jpeg...
# Processing images/train/Lemonada/540.jpeg...
# Processing images/train/Lemonada/541.jpeg...
# Processing images/train/Lemonada/542.jpeg...
# Processing images/train/Lemonada/543.jpeg...
# Processing images/train/Lemonada/544.jpeg...
# Processing images/train/Lemonada/545.jpeg...
# Processing images/train/Lemonada/546.jpeg...
# Processing images/train/Lemonada/547.jpeg...
# Processing images/train/Lemonada/548.jpeg...
# Processing images/train/Lemonada/549.jpeg...
# Processing images/train/Lemonada/55.jpeg...
# Processing images/train/Lemonada/550.jpeg...
# Processing images/train/Lemonada/551.jpeg...
# Processing images/train/Lemonada/552.jpeg...
# Processing images/train/Lemonada/553.jpeg...
# Processing images/train/Lemonada/554.jpeg...
# Processing images/train/Lemonada/555.jpeg...
# Processing images/train/Lemonada/556.jpeg...
# Processing images/train/Lemonada/557.jpeg...
# Processing images/train/Lemonada/558.jpeg...
# Processing images/train/Lemonada/559.jpeg...
# Processing images/train/Lemonada/56.jpeg...
# Processing images/train/Lemonada/560.jpeg...
# Processing images/train/Lemonada/561.jpeg...
# Processing images/train/Lemonada/562.jpeg...
# Processing images/train/Lemonada/563.jpeg...
# Processing images/train/Lemonada/564.jpeg...
# Processing images/train/Lemonada/565.jpeg...
# Processing images/train/Lemonada/566.jpeg...
# Processing images/train/Lemonada/567.jpeg...
# Processing images/train/Lemonada/568.jpeg...
# Processing images/train/Lemonada/569.jpeg...
# Processing images/train/Lemonada/57.jpeg...
# Processing images/train/Lemonada/570.jpeg...
# Processing images/train/Lemonada/571.jpeg...
# Processing images/train/Lemonada/572.jpeg...
# Processing images/train/Lemonada/573.jpeg...
# Processing images/train/Lemonada/574.jpeg...
# Processing images/train/Lemonada/575.jpeg...
# Processing images/train/Lemonada/576.jpeg...
# Processing images/train/Lemonada/577.jpeg...
# Processing images/train/Lemonada/578.jpeg...
# Processing images/train/Lemonada/579.jpeg...
# Processing images/train/Lemonada/58.jpeg...
# Processing images/train/Lemonada/580.jpeg...
# Processing images/train/Lemonada/581.jpeg...
# Processing images/train/Lemonada/582.jpeg...
# Processing images/train/Lemonada/583.jpeg...
# Processing images/train/Lemonada/584.jpeg...
# Processing images/train/Lemonada/585.jpeg...
# Processing images/train/Lemonada/586.jpeg...
# Processing images/train/Lemonada/587.jpeg...
# Processing images/train/Lemonada/588.jpeg...
# Processing images/train/Lemonada/589.jpeg...
# Processing images/train/Lemonada/59.jpeg...
# Processing images/train/Lemonada/590.jpeg...
# Processing images/train/Lemonada/591.jpeg...
# Processing images/train/Lemonada/592.jpeg...
# Processing images/train/Lemonada/593.jpeg...
# Processing images/train/Lemonada/594.jpeg...
# Processing images/train/Lemonada/595.jpeg...
# Processing images/train/Lemonada/596.jpeg...
# Processing images/train/Lemonada/597.jpeg...
# Processing images/train/Lemonada/598.jpeg...
# Processing images/train/Lemonada/599.jpeg...
# Processing images/train/Lemonada/6.jpeg...
# Processing images/train/Lemonada/60.jpeg...
# Processing images/train/Lemonada/600.jpeg...
# Processing images/train/Lemonada/601.jpeg...
# Processing images/train/Lemonada/602.jpeg...
# Processing images/train/Lemonada/603.jpeg...
# Processing images/train/Lemonada/604.jpeg...
# Processing images/train/Lemonada/605.jpeg...
# Processing images/train/Lemonada/606.jpeg...
# Processing images/train/Lemonada/607.jpeg...
# Processing images/train/Lemonada/608.jpeg...
# Processing images/train/Lemonada/609.jpeg...
# Processing images/train/Lemonada/61.jpeg...
# Processing images/train/Lemonada/610.jpeg...
# Processing images/train/Lemonada/611.jpeg...
# Processing images/train/Lemonada/612.jpeg...
# Processing images/train/Lemonada/613.jpeg...
# Processing images/train/Lemonada/614.jpeg...
# Processing images/train/Lemonada/615.jpeg...
# Processing images/train/Lemonada/616.jpeg...
# Processing images/train/Lemonada/617.jpeg...
# Processing images/train/Lemonada/618.jpeg...
# Processing images/train/Lemonada/619.jpeg...
# Processing images/train/Lemonada/62.jpeg...
# Processing images/train/Lemonada/620.jpeg...
# Processing images/train/Lemonada/621.jpeg...
# Processing images/train/Lemonada/622.jpeg...
# Processing images/train/Lemonada/623.jpeg...
# Processing images/train/Lemonada/624.jpeg...
# Processing images/train/Lemonada/625.jpeg...
# Processing images/train/Lemonada/626.jpeg...
# Processing images/train/Lemonada/627.jpeg...
# Processing images/train/Lemonada/628.jpeg...
# Processing images/train/Lemonada/629.jpeg...
# Processing images/train/Lemonada/63.jpeg...
# Processing images/train/Lemonada/630.jpeg...
# Processing images/train/Lemonada/631.jpeg...
# Processing images/train/Lemonada/632.jpeg...
# Processing images/train/Lemonada/633.jpeg...
# Processing images/train/Lemonada/634.jpeg...
# Processing images/train/Lemonada/635.jpeg...
# Processing images/train/Lemonada/636.jpeg...
# Processing images/train/Lemonada/637.jpeg...
# Processing images/train/Lemonada/638.jpeg...
# Processing images/train/Lemonada/639.jpeg...
# Processing images/train/Lemonada/64.jpeg...
# Processing images/train/Lemonada/640.jpeg...
# Processing images/train/Lemonada/641.jpeg...
# Processing images/train/Lemonada/642.jpeg...
# Processing images/train/Lemonada/643.jpeg...
# Processing images/train/Lemonada/644.jpeg...
# Processing images/train/Lemonada/645.jpeg...
# Processing images/train/Lemonada/646.jpeg...
# Processing images/train/Lemonada/647.jpeg...
# Processing images/train/Lemonada/648.jpeg...
# Processing images/train/Lemonada/649.jpeg...
# Processing images/train/Lemonada/65.jpeg...
# Processing images/train/Lemonada/650.jpeg...
# Processing images/train/Lemonada/651.jpeg...
# Processing images/train/Lemonada/652.jpeg...
# Processing images/train/Lemonada/653.jpeg...
# Processing images/train/Lemonada/654.jpeg...
# Processing images/train/Lemonada/655.jpeg...
# Processing images/train/Lemonada/656.jpeg...
# Processing images/train/Lemonada/657.jpeg...
# Processing images/train/Lemonada/658.jpeg...
# Processing images/train/Lemonada/659.jpeg...
# Processing images/train/Lemonada/66.jpeg...
# Processing images/train/Lemonada/660.jpeg...
# Processing images/train/Lemonada/661.jpeg...
# Processing images/train/Lemonada/662.jpeg...
# Processing images/train/Lemonada/663.jpeg...
# Processing images/train/Lemonada/664.jpeg...
# Processing images/train/Lemonada/665.jpeg...
# Processing images/train/Lemonada/666.jpeg...
# Processing images/train/Lemonada/667.jpeg...
# Processing images/train/Lemonada/668.jpeg...
# Processing images/train/Lemonada/669.jpeg...
# Processing images/train/Lemonada/67.jpeg...
# Processing images/train/Lemonada/670.jpeg...
# Processing images/train/Lemonada/671.jpeg...
# Processing images/train/Lemonada/672.jpeg...
# Processing images/train/Lemonada/673.jpeg...
# Processing images/train/Lemonada/674.jpeg...
# Processing images/train/Lemonada/675.jpeg...
# Processing images/train/Lemonada/676.jpeg...
# Processing images/train/Lemonada/677.jpeg...
# Processing images/train/Lemonada/678.jpeg...
# Processing images/train/Lemonada/679.jpeg...
# Processing images/train/Lemonada/68.jpeg...
# Processing images/train/Lemonada/680.jpeg...
# Processing images/train/Lemonada/681.jpeg...
# Processing images/train/Lemonada/682.jpeg...
# Processing images/train/Lemonada/683.jpeg...
# Processing images/train/Lemonada/684.jpeg...
# Processing images/train/Lemonada/685.jpeg...
# Processing images/train/Lemonada/686.jpeg...
# Processing images/train/Lemonada/687.jpeg...
# Processing images/train/Lemonada/688.jpeg...
# Processing images/train/Lemonada/689.jpeg...
# Processing images/train/Lemonada/69.jpeg...
# Processing images/train/Lemonada/690.jpeg...
# Processing images/train/Lemonada/691.jpeg...
# Processing images/train/Lemonada/692.jpeg...
# Processing images/train/Lemonada/693.jpeg...
# Processing images/train/Lemonada/694.jpeg...
# Processing images/train/Lemonada/695.jpeg...
# Processing images/train/Lemonada/696.jpeg...
# Processing images/train/Lemonada/697.jpeg...
# Processing images/train/Lemonada/698.jpeg...
# Processing images/train/Lemonada/699.jpeg...
# Processing images/train/Lemonada/7.jpeg...
# Processing images/train/Lemonada/70.jpeg...
# Processing images/train/Lemonada/700.jpeg...
# Processing images/train/Lemonada/701.jpeg...
# Processing images/train/Lemonada/702.jpeg...
# Processing images/train/Lemonada/703.jpeg...
# Processing images/train/Lemonada/704.jpeg...
# Processing images/train/Lemonada/705.jpeg...
# Processing images/train/Lemonada/706.jpeg...
# Processing images/train/Lemonada/707.jpeg...
# Processing images/train/Lemonada/708.jpeg...
# Processing images/train/Lemonada/709.jpeg...
# Processing images/train/Lemonada/71.jpeg...
# Processing images/train/Lemonada/710.jpeg...
# Processing images/train/Lemonada/711.jpeg...
# Processing images/train/Lemonada/712.jpeg...
# Processing images/train/Lemonada/713.jpeg...
# Processing images/train/Lemonada/714.jpeg...
# Processing images/train/Lemonada/715.jpeg...
# Processing images/train/Lemonada/716.jpeg...
# Processing images/train/Lemonada/717.jpeg...
# Processing images/train/Lemonada/718.jpeg...
# Processing images/train/Lemonada/719.jpeg...
# Processing images/train/Lemonada/72.jpeg...
# Processing images/train/Lemonada/720.jpeg...
# Processing images/train/Lemonada/721.jpeg...
# Processing images/train/Lemonada/722.jpeg...
# Processing images/train/Lemonada/723.jpeg...
# Processing images/train/Lemonada/724.jpeg...
# Processing images/train/Lemonada/725.jpeg...
# Processing images/train/Lemonada/726.jpeg...
# Processing images/train/Lemonada/727.jpeg...
# Processing images/train/Lemonada/728.jpeg...
# Processing images/train/Lemonada/729.jpeg...
# Processing images/train/Lemonada/73.jpeg...
# Processing images/train/Lemonada/730.jpeg...
# Processing images/train/Lemonada/731.jpeg...
# Processing images/train/Lemonada/732.jpeg...
# Processing images/train/Lemonada/733.jpeg...
# Processing images/train/Lemonada/734.jpeg...
# Processing images/train/Lemonada/735.jpeg...
# Processing images/train/Lemonada/736.jpeg...
# Processing images/train/Lemonada/737.jpeg...
# Processing images/train/Lemonada/738.jpeg...
# Processing images/train/Lemonada/739.jpeg...
# Processing images/train/Lemonada/74.jpeg...
# Processing images/train/Lemonada/740.jpeg...
# Processing images/train/Lemonada/741.jpeg...
# Processing images/train/Lemonada/742.jpeg...
# Processing images/train/Lemonada/743.jpeg...
# Processing images/train/Lemonada/744.jpeg...
# Processing images/train/Lemonada/745.jpeg...
# Processing images/train/Lemonada/746.jpeg...
# Processing images/train/Lemonada/747.jpeg...
# Processing images/train/Lemonada/748.jpeg...
# Processing images/train/Lemonada/749.jpeg...
# Processing images/train/Lemonada/75.jpeg...
# Processing images/train/Lemonada/750.jpeg...
# Processing images/train/Lemonada/751.jpeg...
# Processing images/train/Lemonada/752.jpeg...
# Processing images/train/Lemonada/753.jpeg...
# Processing images/train/Lemonada/754.jpeg...
# Processing images/train/Lemonada/755.jpeg...
# Processing images/train/Lemonada/756.jpeg...
# Processing images/train/Lemonada/757.jpeg...
# Processing images/train/Lemonada/758.jpeg...
# Processing images/train/Lemonada/759.jpeg...
# Processing images/train/Lemonada/76.jpeg...
# Processing images/train/Lemonada/760.jpeg...
# Processing images/train/Lemonada/761.jpeg...
# Processing images/train/Lemonada/762.jpeg...
# Processing images/train/Lemonada/763.jpeg...
# Processing images/train/Lemonada/764.jpeg...
# Processing images/train/Lemonada/765.jpeg...
# Processing images/train/Lemonada/766.jpeg...
# Processing images/train/Lemonada/767.jpeg...
# Processing images/train/Lemonada/768.jpeg...
# Processing images/train/Lemonada/769.jpeg...
# Processing images/train/Lemonada/77.jpeg...
# Processing images/train/Lemonada/770.jpeg...
# Processing images/train/Lemonada/771.jpeg...
# Processing images/train/Lemonada/772.jpeg...
# Processing images/train/Lemonada/773.jpeg...
# Processing images/train/Lemonada/774.jpeg...
# Processing images/train/Lemonada/775.jpeg...
# Processing images/train/Lemonada/776.jpeg...
# Processing images/train/Lemonada/777.jpeg...
# Processing images/train/Lemonada/778.jpeg...
# Processing images/train/Lemonada/779.jpeg...
# Processing images/train/Lemonada/78.jpeg...
# Processing images/train/Lemonada/780.jpeg...
# Processing images/train/Lemonada/781.jpeg...
# Processing images/train/Lemonada/782.jpeg...
# Processing images/train/Lemonada/783.jpeg...
# Processing images/train/Lemonada/784.jpeg...
# Processing images/train/Lemonada/785.jpeg...
# Processing images/train/Lemonada/786.jpeg...
# Processing images/train/Lemonada/787.jpeg...
# Processing images/train/Lemonada/788.jpeg...
# Processing images/train/Lemonada/789.jpeg...
# Processing images/train/Lemonada/79.jpeg...
# Processing images/train/Lemonada/790.jpeg...
# Processing images/train/Lemonada/791.jpeg...
# Processing images/train/Lemonada/792.jpeg...
# Processing images/train/Lemonada/793.jpeg...
# Processing images/train/Lemonada/794.jpeg...
# Processing images/train/Lemonada/795.jpeg...
# Processing images/train/Lemonada/796.jpeg...
# Processing images/train/Lemonada/797.jpeg...
# Processing images/train/Lemonada/798.jpeg...
# Processing images/train/Lemonada/799.jpeg...
# Processing images/train/Lemonada/8.jpeg...
# Processing images/train/Lemonada/80.jpeg...
# Processing images/train/Lemonada/800.jpeg...
# Processing images/train/Lemonada/801.jpeg...
# Processing images/train/Lemonada/802.jpeg...
# Processing images/train/Lemonada/803.jpeg...
# Processing images/train/Lemonada/804.jpeg...
# Processing images/train/Lemonada/805.jpeg...
# Processing images/train/Lemonada/806.jpeg...
# Processing images/train/Lemonada/807.jpeg...
# Processing images/train/Lemonada/808.jpeg...
# Processing images/train/Lemonada/809.jpeg...
# Processing images/train/Lemonada/81.jpeg...
# Processing images/train/Lemonada/810.jpeg...
# Processing images/train/Lemonada/811.jpeg...
# Processing images/train/Lemonada/812.jpeg...
# Processing images/train/Lemonada/813.jpeg...
# Processing images/train/Lemonada/814.jpeg...
# Processing images/train/Lemonada/815.jpeg...
# Processing images/train/Lemonada/816.jpeg...
# Processing images/train/Lemonada/817.jpeg...
# Processing images/train/Lemonada/818.jpeg...
# Processing images/train/Lemonada/819.jpeg...
# Processing images/train/Lemonada/82.jpeg...
# Processing images/train/Lemonada/820.jpeg...
# Processing images/train/Lemonada/821.jpeg...
# Processing images/train/Lemonada/822.jpeg...
# Processing images/train/Lemonada/823.jpeg...
# Processing images/train/Lemonada/824.jpeg...
# Processing images/train/Lemonada/825.jpeg...
# Processing images/train/Lemonada/826.jpeg...
# Processing images/train/Lemonada/827.jpeg...
# Processing images/train/Lemonada/828.jpeg...
# Processing images/train/Lemonada/829.jpeg...
# Processing images/train/Lemonada/83.jpeg...
# Processing images/train/Lemonada/830.jpeg...
# Processing images/train/Lemonada/831.jpeg...
# Processing images/train/Lemonada/832.jpeg...
# Processing images/train/Lemonada/833.jpeg...
# Processing images/train/Lemonada/834.jpeg...
# Processing images/train/Lemonada/835.jpeg...
# Processing images/train/Lemonada/836.jpeg...
# Processing images/train/Lemonada/837.jpeg...
# Processing images/train/Lemonada/838.jpeg...
# Processing images/train/Lemonada/839.jpeg...
# Processing images/train/Lemonada/84.jpeg...
# Processing images/train/Lemonada/840.jpeg...
# Processing images/train/Lemonada/841.jpeg...
# Processing images/train/Lemonada/842.jpeg...
# Processing images/train/Lemonada/843.jpeg...
# Processing images/train/Lemonada/844.jpeg...
# Processing images/train/Lemonada/845.jpeg...
# Processing images/train/Lemonada/846.jpeg...
# Processing images/train/Lemonada/847.jpeg...
# Processing images/train/Lemonada/848.jpeg...
# Processing images/train/Lemonada/849.jpeg...
# Processing images/train/Lemonada/85.jpeg...
# Processing images/train/Lemonada/850.jpeg...
# Processing images/train/Lemonada/851.jpeg...
# Processing images/train/Lemonada/852.jpeg...
# Processing images/train/Lemonada/853.jpeg...
# Processing images/train/Lemonada/854.jpeg...
# Processing images/train/Lemonada/855.jpeg...
# Processing images/train/Lemonada/856.jpeg...
# Processing images/train/Lemonada/857.jpeg...
# Processing images/train/Lemonada/858.jpeg...
# Processing images/train/Lemonada/859.jpeg...
# Processing images/train/Lemonada/86.jpeg...
# Processing images/train/Lemonada/860.jpeg...
# Processing images/train/Lemonada/861.jpeg...
# Processing images/train/Lemonada/862.jpeg...
# Processing images/train/Lemonada/863.jpeg...
# Processing images/train/Lemonada/864.jpeg...
# Processing images/train/Lemonada/865.jpeg...
# Processing images/train/Lemonada/866.jpeg...
# Processing images/train/Lemonada/867.jpeg...
# Processing images/train/Lemonada/868.jpeg...
# Processing images/train/Lemonada/869.jpeg...
# Processing images/train/Lemonada/87.jpeg...
# Processing images/train/Lemonada/870.jpeg...
# Processing images/train/Lemonada/871.jpeg...
# Processing images/train/Lemonada/872.jpeg...
# Processing images/train/Lemonada/873.jpeg...
# Processing images/train/Lemonada/874.jpeg...
# Processing images/train/Lemonada/875.jpeg...
# Processing images/train/Lemonada/876.jpeg...
# Processing images/train/Lemonada/877.jpeg...
# Processing images/train/Lemonada/878.jpeg...
# Processing images/train/Lemonada/879.jpeg...
# Processing images/train/Lemonada/88.jpeg...
# Processing images/train/Lemonada/880.jpeg...
# Processing images/train/Lemonada/881.jpeg...
# Processing images/train/Lemonada/882.jpeg...
# Processing images/train/Lemonada/883.jpeg...
# Processing images/train/Lemonada/884.jpeg...
# Processing images/train/Lemonada/885.jpeg...
# Processing images/train/Lemonada/886.jpeg...
# Processing images/train/Lemonada/887.jpeg...
# Processing images/train/Lemonada/888.jpeg...
# Processing images/train/Lemonada/889.jpeg...
# Processing images/train/Lemonada/89.jpeg...
# Processing images/train/Lemonada/890.jpeg...
# Processing images/train/Lemonada/891.jpeg...
# Processing images/train/Lemonada/892.jpeg...
# Processing images/train/Lemonada/893.jpeg...
# Processing images/train/Lemonada/894.jpeg...
# Processing images/train/Lemonada/895.jpeg...
# Processing images/train/Lemonada/896.jpeg...
# Processing images/train/Lemonada/897.jpeg...
# Processing images/train/Lemonada/898.jpeg...
# Processing images/train/Lemonada/899.jpeg...
# Processing images/train/Lemonada/9.jpeg...
# Processing images/train/Lemonada/90.jpeg...
# Processing images/train/Lemonada/900.jpeg...
# Processing images/train/Lemonada/901.jpeg...
# Processing images/train/Lemonada/902.jpeg...
# Processing images/train/Lemonada/903.jpeg...
# Processing images/train/Lemonada/904.jpeg...
# Processing images/train/Lemonada/905.jpeg...
# Processing images/train/Lemonada/906.jpeg...
# Processing images/train/Lemonada/907.jpeg...
# Processing images/train/Lemonada/908.jpeg...
# Processing images/train/Lemonada/909.jpeg...
# Processing images/train/Lemonada/91.jpeg...
# Processing images/train/Lemonada/910.jpeg...
# Processing images/train/Lemonada/911.jpeg...
# Processing images/train/Lemonada/912.jpeg...
# Processing images/train/Lemonada/913.jpeg...
# Processing images/train/Lemonada/914.jpeg...
# Processing images/train/Lemonada/915.jpeg...
# Processing images/train/Lemonada/916.jpeg...
# Processing images/train/Lemonada/917.jpeg...
# Processing images/train/Lemonada/918.jpeg...
# Processing images/train/Lemonada/919.jpeg...
# Processing images/train/Lemonada/92.jpeg...
# Processing images/train/Lemonada/920.jpeg...
# Processing images/train/Lemonada/921.jpeg...
# Processing images/train/Lemonada/922.jpeg...
# Processing images/train/Lemonada/923.jpeg...
# Processing images/train/Lemonada/924.jpeg...
# Processing images/train/Lemonada/925.jpeg...
# Processing images/train/Lemonada/926.jpeg...
# Processing images/train/Lemonada/927.jpeg...
# Processing images/train/Lemonada/928.jpeg...
# Processing images/train/Lemonada/929.jpeg...
# Processing images/train/Lemonada/93.jpeg...
# Processing images/train/Lemonada/930.jpeg...
# Processing images/train/Lemonada/931.jpeg...
# Processing images/train/Lemonada/932.jpeg...
# Processing images/train/Lemonada/933.jpeg...
# Processing images/train/Lemonada/934.jpeg...
# Processing images/train/Lemonada/935.jpeg...
# Processing images/train/Lemonada/936.jpeg...
# Processing images/train/Lemonada/937.jpeg...
# Processing images/train/Lemonada/938.jpeg...
# Processing images/train/Lemonada/939.jpeg...
# Processing images/train/Lemonada/94.jpeg...
# Processing images/train/Lemonada/940.jpeg...
# Processing images/train/Lemonada/941.jpeg...
# Processing images/train/Lemonada/942.jpeg...
# Processing images/train/Lemonada/943.jpeg...
# Processing images/train/Lemonada/944.jpeg...
# Processing images/train/Lemonada/945.jpeg...
# Processing images/train/Lemonada/946.jpeg...
# Processing images/train/Lemonada/947.jpeg...
# Processing images/train/Lemonada/948.jpeg...
# Processing images/train/Lemonada/949.jpeg...
# Processing images/train/Lemonada/95.jpeg...
# Processing images/train/Lemonada/950.jpeg...
# Processing images/train/Lemonada/951.jpeg...
# Processing images/train/Lemonada/952.jpeg...
# Processing images/train/Lemonada/953.jpeg...
# Processing images/train/Lemonada/954.jpeg...
# Processing images/train/Lemonada/955.jpeg...
# Processing images/train/Lemonada/956.jpeg...
# Processing images/train/Lemonada/957.jpeg...
# Processing images/train/Lemonada/958.jpeg...
# Processing images/train/Lemonada/959.jpeg...
# Processing images/train/Lemonada/96.jpeg...
# Processing images/train/Lemonada/960.jpeg...
# Processing images/train/Lemonada/961.jpeg...
# Processing images/train/Lemonada/962.jpeg...
# Processing images/train/Lemonada/963.jpeg...
# Processing images/train/Lemonada/964.jpeg...
# Processing images/train/Lemonada/965.jpeg...
# Processing images/train/Lemonada/966.jpeg...
# Processing images/train/Lemonada/967.jpeg...
# Processing images/train/Lemonada/968.jpeg...
# Processing images/train/Lemonada/969.jpeg...
# Processing images/train/Lemonada/97.jpeg...
# Processing images/train/Lemonada/970.jpeg...
# Processing images/train/Lemonada/971.jpeg...
# Processing images/train/Lemonada/972.jpeg...
# Processing images/train/Lemonada/973.jpeg...
# Processing images/train/Lemonada/974.jpeg...
# Processing images/train/Lemonada/975.jpeg...
# Processing images/train/Lemonada/976.jpeg...
# Processing images/train/Lemonada/977.jpeg...
# Processing images/train/Lemonada/978.jpeg...
# Processing images/train/Lemonada/979.jpeg...
# Processing images/train/Lemonada/98.jpeg...
# Processing images/train/Lemonada/980.jpeg...
# Processing images/train/Lemonada/981.jpeg...
# Processing images/train/Lemonada/982.jpeg...
# Processing images/train/Lemonada/983.jpeg...
# Processing images/train/Lemonada/984.jpeg...
# Processing images/train/Lemonada/985.jpeg...
# Processing images/train/Lemonada/986.jpeg...
# Processing images/train/Lemonada/987.jpeg...
# Processing images/train/Lemonada/988.jpeg...
# Processing images/train/Lemonada/989.jpeg...
# Processing images/train/Lemonada/99.jpeg...
# Processing images/train/Lemonada/990.jpeg...
# Processing images/train/Lemonada/991.jpeg...
# Processing images/train/Lemonada/992.jpeg...
# Processing images/train/Lemonada/993.jpeg...
# Processing images/train/Lemonada/994.jpeg...
# Processing images/train/Lemonada/995.jpeg...
# Processing images/train/Lemonada/996.jpeg...
# Processing images/train/Lemonada/997.jpeg...
# Processing images/train/Lemonada/998.jpeg...
# Processing images/train/Lemonada/999.jpeg...
